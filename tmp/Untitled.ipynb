# %%
import json
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


DATASET_DAY = "Clear sky"
# DATASET_DAY = "Overcast"
# DATASET_DAY = "Variable"
# DATASET_DAY = "Very variable"
DATASET_PLACE = "Varennes"
DATASET_FREC = "1000"  # For "Variable" (1 ins/s)
# DATASET_FREC = "500"  # For "Very variable" (2 ins/s)

DATE = time.strftime("%Y-%m-%d_%H-%M", time.localtime())
DATA_PATH = f"./data/{DATASET_DAY}/{DATASET_PLACE}_{DATASET_FREC}ms.csv"
PARAM_PATH = f"./data/{DATASET_DAY}/{DATASET_PLACE}_{DATASET_FREC}ms_params.json"
OUT_PATH = f"./results/{DATASET_DAY}/{DATE}_grafica.png"


# Read datasets
with open(PARAM_PATH) as fparams:
    params = json.load(fparams)
min_value = params["min"]
max_value = params["max"]

data = pd.read_csv(DATA_PATH)
data.drop(data.columns[0], axis="columns", inplace=True)

# Create image
for i, col in enumerate(data.columns):
    if i != 3: continue
    
    s = data[col]
    plt.plot(s)
    plt.show()
        
    s = data[col].drop(data[data[col] == 0].index, axis=0, inplace=False)
    for _ in range(10):
        s = s.drop(s[s == s.min()].index, axis=0, inplace=False)
    print(np.unique(s))
    plt.plot(s)
    plt.show()

# data = np.sin(np.linspace(0, 100, 10_000))
# plt.plot(data)

# Write results
if not os.path.exists(os.path.dirname(OUT_PATH)):
    os.makedirs(os.path.dirname(OUT_PATH))
# Out:
# [0.02842377 0.03100775 0.03359173 0.03617571 0.03875969 0.04134367
#  0.04392765 0.04651163 0.04909561 0.05167959 0.05426357 0.05684755
#  0.05943152 0.0620155  0.06459948 0.06718346 0.06976744 0.07235142
#  0.0749354  0.07751938 0.08010336 0.08268734 0.0878553  0.09043928
#  0.09302326 0.09560724 0.09819121 0.10335917 0.10594315 0.10852713
#  0.11111111 0.11369509 0.11627907 0.11886305 0.12144703 0.12403101
#  0.12661499 0.12919897 0.13178295 0.13436693 0.1369509  0.13953488
#  0.14211886 0.14470284 0.14728682 0.1498708  0.15245478 0.15503876
#  0.15762274 0.16020672 0.1627907  0.16537468 0.17054264 0.17312661
#  0.17571059 0.17829457 0.18087855 0.18346253 0.18604651 0.18863049
#  0.19379845 0.19638243 0.19896641 0.20155039 0.20413437 0.20671835
#  0.20930233 0.2118863  0.21447028 0.21705426 0.21963824 0.22222222
#  0.22739018 0.22997416 0.23255814 0.23514212 0.2377261  0.24289406
#  0.24547804 0.24806202 0.25064599 0.25581395 0.25839793 0.26356589
#  0.26614987 0.27131783 0.27648579 0.27906977 0.28165375 0.28423773
#  0.28682171 0.28940568 0.29198966 0.29715762 0.30232558 0.30490956
#  0.30749354 0.31007752 0.3126615  0.31524548 0.31782946 0.32041344
#  0.32299742 0.3255814  0.32816537 0.33074935 0.33591731 0.33850129
#  0.34108527 0.34366925 0.34625323 0.34883721 0.35142119 0.35400517
#  0.35658915 0.35917313 0.36175711 0.36434109 0.36692506 0.36950904
